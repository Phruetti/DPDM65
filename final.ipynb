# %% [markdown]
# <a href="https://colab.research.google.com/github/Phruetti/DPDM65/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data_train = pd.read_csv('/content/drive/MyDrive/DPDM65/train.csv')
data_train
# Out:
#       Unnamed: 0       id                    project_name  \
# 0              0    676.0         กันยารัตน์ ฟลอร่า วิลล์
# 1              1  19711.0                             NaN
# 2              2   30146P                             NaN
# 3              3   1899.0                             NaN
# 4              4  23503.0                             NaN
# ...          ...      ...                             ...
# 2720        2720   5130.0   เดอะ มอร์ ศรีจันทร์ ขอนแก่น
# 2721        2721   30284P                             NaN
# 2722        2722   6326.0                             NaN
# 2723        2723   6045.0  กันยารัตน์ การ์เด้นวิว รีสอร์ท
# 2724        2724  18085.0                             NaN
#
#                                     company province      district  \
# 0     บริษัท กันยารัตน์ พร็อพเพอร์ตี้ จำกัด  ขอนแก่น  เมืองขอนแก่น
# 1                                       NaN  ขอนแก่น  เมืองขอนแก่น
# ...

# %%
data_test = pd.read_csv('/content/drive/MyDrive/DPDM65/additional_data_newhouse.csv')
data_test
# Out:
#      Unnamed: 0                        id                 parent_id  \
# 0             0                     314.0                      41.0
# 1             1                     315.0                      41.0
# 2             2                     316.0                      41.0
# 3             3                     317.0                      41.0
# 4             4                     318.0                      41.0
# ..          ...                       ...                       ...
# 988         988  5fa0e476a3326800191e29ea  5fa10335d0235b0019c19548
# 989         989  5e9d6fa69f161600121b61b2  5e9d70b19f161600121b61bc
# 990         990  5e9d6fa69f161600121b61b2  5e9d70379f161600121b61b7
# 991         991  5e9d6fa69f161600121b61b2  5e9d71739f161600121b61c2
# 992         992  5ea938d968253d0012adc1e2  5ea9391e68253d0012adc1e5
#
#                  project_name province      district sub_district  zip_code  \
# ...

# %% [markdown]
# ### cleaning data

# %%
import numpy as np

# %%
data_train.shape
# Out:
# (2725, 41)

# %%
data_test.shape
# Out:
# (993, 139)

# %%
data_train.dtypes
# Out:
# Unnamed: 0              int64
# id                     object
# project_name           object
# company                object
# province               object
# district               object
# sub_district           object
# property_type          object
# home improvement       object
# renovate               object
# public utility         object
# land type              object
# land wide(m)          float64
# land long(m)           object
# topsoil                object
# corner                 object
# zip_code              float64
# zone                   object
# alley                  object
# street                 object
# latitude               object
# longitude              object
# number_of_rai         float64
# number_of_ngan         object
# number_of_va          float64
# construct_year        float64
# model                 float64
# sell_price            float64
# number_of_unit         object
# number_of_story        object
# number_of_bedroom      object
# ...

# %%
data_test.dtypes
# Out:
# Unnamed: 0             int64
# id                    object
# parent_id             object
# project_name          object
# province              object
#                       ...
# cable_ask            float64
# position_previous    float64
# position_current     float64
# sold_out_at          float64
# is_pro_in_house      float64
# Length: 139, dtype: object

# %%
data_train['sell_price'] = pd.to_numeric(data_train['sell_price'],errors='coerce')
data_train.describe()
# Out:
#         Unnamed: 0  land wide(m)      zip_code  number_of_rai  number_of_va  \
# count  2725.000000    315.000000  1.741000e+03    2725.000000   2725.000000
# mean   1362.000000     55.456159  4.635122e+06       3.561101     44.054606
# std     786.784066     75.585414  1.355348e+08      15.905963     58.956727
# min       0.000000      4.000000  4.000000e+04       0.000000      0.000000
# 25%     681.000000     12.000000  4.000000e+04       0.000000      5.000000
# 50%    1362.000000     27.500000  4.000000e+04       0.000000     35.000000
# 75%    2043.000000     65.000000  4.013000e+04       0.000000     66.000000
# max    2724.000000    420.000000  4.000040e+09     458.000000   1656.000000
#
#        construct_year  model    sell_price
# count             0.0    0.0  2.715000e+03
# mean              NaN    NaN  2.837311e+07
# std               NaN    NaN  7.713639e+08
# min               NaN    NaN  0.000000e+00
# 25%               NaN    NaN  1.450000e+06
# ...

# %%
mean_tr=data_train['sell_price'].mean()
mean_tr
# Out:
# 28373107.167219155

# %%
from matplotlib import pyplot as plt

# %%
data_train['SELL']=data_train['sell_price']>=28373107 #มากกว่าเท่ากับ 10
data_train
# Out:
#       Unnamed: 0       id                    project_name  \
# 0              0    676.0         กันยารัตน์ ฟลอร่า วิลล์
# 1              1  19711.0                             NaN
# 2              2   30146P                             NaN
# 3              3   1899.0                             NaN
# 4              4  23503.0                             NaN
# ...          ...      ...                             ...
# 2720        2720   5130.0   เดอะ มอร์ ศรีจันทร์ ขอนแก่น
# 2721        2721   30284P                             NaN
# 2722        2722   6326.0                             NaN
# 2723        2723   6045.0  กันยารัตน์ การ์เด้นวิว รีสอร์ท
# 2724        2724  18085.0                             NaN
#
#                                     company province      district  \
# 0     บริษัท กันยารัตน์ พร็อพเพอร์ตี้ จำกัด  ขอนแก่น  เมืองขอนแก่น
# 1                                       NaN  ขอนแก่น  เมืองขอนแก่น
# ...

# %%
df_pr=pd.get_dummies(data_train,columns=['Sex']) 
df_pr
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-5225fb3017e9> in <module>
# ----> 1 df_pr=pd.get_dummies(data_train,columns=['Sex'])
#       2 df_pr
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     888             raise TypeError("Input must be a list-like for parameter `columns`")
#     889         else:
# --> 890             data_to_encode = data[columns]
#     891
#     892         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
# ...

# %% [markdown]
# ###เริ่มทำ data Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
TRAIN = data_train.iloc[:1900,:]
TEST = data_train.iloc[1900:,:]
print(f'train={TRAIN.shape[0]},test={TEST.shape[0]}')
# Out:
# train=1900,test=825

# %%
x=TRAIN.drop(columns=['sell_price'])
x
# Out:
#       Unnamed: 0       id                  project_name  \
# 0              0    676.0       กันยารัตน์ ฟลอร่า วิลล์
# 1              1  19711.0                           NaN
# 2              2   30146P                           NaN
# 3              3   1899.0                           NaN
# 4              4  23503.0                           NaN
# ...          ...      ...                           ...
# 1895        1895  20146.0             สุรินดา กลางเมือง
# 1896        1896   20391P                           NaN
# 1897        1897   10385P  เดอะ เบสไฮท์ มิตรภาพ ขอนแก่น
# 1898        1898   8924.0                           NaN
# 1899        1899  17505.0                           NaN
#
#                                     company province      district  \
# 0     บริษัท กันยารัตน์ พร็อพเพอร์ตี้ จำกัด  ขอนแก่น  เมืองขอนแก่น
# 1                                       NaN  ขอนแก่น  เมืองขอนแก่น
# 2                                       NaN  ขอนแก่น  เมืองขอนแก่น
# ...

# %%
y=TRAIN.iloc[:,10]
y
# Out:
# 0           NaN
# 1           yes
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 1895        NaN
# 1896    ไม่ระบุ
# 1897        NaN
# 1898    ไม่ระบุ
# 1899        NaN
# Name: public utility, Length: 1900, dtype: object

# %%
plt.figure(figsize=(12,9))
plt.scatter(TRAIN["x"], TEST["y"])
plt.xlabel("x")
plt.ylabel("y")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
x_train=TRAIN.drop(columns=['sell_price'])
x_train
# Out:
#       Unnamed: 0       id                  project_name  \
# 0              0    676.0       กันยารัตน์ ฟลอร่า วิลล์
# 1              1  19711.0                           NaN
# 2              2   30146P                           NaN
# 3              3   1899.0                           NaN
# 4              4  23503.0                           NaN
# ...          ...      ...                           ...
# 1895        1895  20146.0             สุรินดา กลางเมือง
# 1896        1896   20391P                           NaN
# 1897        1897   10385P  เดอะ เบสไฮท์ มิตรภาพ ขอนแก่น
# 1898        1898   8924.0                           NaN
# 1899        1899  17505.0                           NaN
#
#                                     company province      district  \
# 0     บริษัท กันยารัตน์ พร็อพเพอร์ตี้ จำกัด  ขอนแก่น  เมืองขอนแก่น
# 1                                       NaN  ขอนแก่น  เมืองขอนแก่น
# 2                                       NaN  ขอนแก่น  เมืองขอนแก่น
# ...
